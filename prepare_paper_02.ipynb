# %% [markdown]
# Prepare plots for the paper.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

#plt.style.use('ggplot')
plt.style.use('seaborn-paper')
#mpl.rcParams['xtick.labelsize'] = 7
#mpl.rcParams['ytick.labelsize'] = 7
#mpl.rcParams["image.cmap"] = 'gray'
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['savefig.bbox'] = 'tight'

import datetime
date = datetime.datetime.now().strftime('%Y%m%d')

# %matplotlib inline

# %% [markdown]
# # Update the core list

# %%
from wasafacies import PrepareData

prepare = PrepareData()
facies, id_list = prepare.create_recla()

info_df = pd.read_csv('data/info.cleaned.all.csv', index_col=0, 
                      usecols=['composite_id', 'core_section', 'long_utm', 'lat_utm'])

# %%
info_df
# Out:
#                   long_utm core_section       lat_utm
# composite_id
# N10_00001     389460.02166        N10-5  5.956522e+06
# N10_00003     389460.02166        N10-5  5.956522e+06
# N10_00005     389460.02166        N10-5  5.956522e+06
# N10_00007     389460.02166        N10-5  5.956522e+06
# N10_00009     389460.02166        N10-5  5.956522e+06
# ...                    ...          ...           ...
# W6_01840      382469.01300         W6-0  5.944948e+06
# W6_01842      382469.01300         W6-0  5.944948e+06
# W6_01844      382469.01300         W6-0  5.944948e+06
# W6_01846      382469.01300         W6-0  5.944948e+06
# W6_01848      382469.01300         W6-0  5.944948e+06
#
# [170436 rows x 3 columns]

# %%
out = info_df.loc[id_list, ['core_section', 'long_utm', 'lat_utm']].groupby('core_section').mean()
out
# Out:
#                    long_utm       lat_utm
# core_section
# N11-1         372919.501165  5.953943e+06
# N11-2         372919.501165  5.953943e+06
# N13-2         376934.301491  5.953075e+06
# N13-3         376934.301491  5.953075e+06
# N13-4         376934.301491  5.953075e+06
# N14-1         376864.372782  5.952926e+06
# N14-2         376864.372782  5.952926e+06
# N15-1         376821.653110  5.952809e+06
# N15-2         376821.653110  5.952809e+06
# N15-4         376821.653110  5.952809e+06
# N16-1         376841.734706  5.952266e+06
# N16-2         376841.734706  5.952266e+06
# N16-4         376841.734706  5.952266e+06
# N18-2         377685.385503  5.951345e+06
# N18-5         377685.385503  5.951345e+06
# N23-1         378651.401930  5.951120e+06
# N23-2         378651.401930  5.951120e+06
# N23-3         378651.401930  5.951120e+06
# N23-4         378651.401930  5.951120e+06
# N25-3         379239.920731  5.951386e+06
# N26-4         379241.876966  5.951688e+06
# N28-1         380346.656541  5.951310e+06
# N30-4         381025.867668  5.951120e+06
# N31-1         381652.274887  5.951048e+06
# N32-3         381686.377659  5.951042e+06
# N34-2         382519.412273  5.950893e+06
# N36-4         379235.019000  5.950549e+06
# N38-4         382069.307000  5.950267e+06
# N40-1         382740.034902  5.950702e+06
# N40-4         382740.034902  5.950702e+06
# N41-2         383277.960086  5.950829e+06
# N41-4         383277.960086  5.950829e+06
# N43-1         378293.250000  5.949892e+06
# N43-3         378293.250000  5.949892e+06
# N46-1         381670.230000  5.950153e+06
# N49-3         378326.157000  5.948519e+06
# N50-2         380290.610002  5.948761e+06
# N71-1         377706.964230  5.951329e+06
# N71-3         377706.964230  5.951329e+06
# N71-4         377706.964230  5.951329e+06
# N85-3         372220.456356  5.954347e+06
# VC13-2        379692.999989  5.950222e+06
# VVC09-4       385148.892261  5.950229e+06
# VVC16-4       376509.279955  5.949859e+06
# VVC17-1       376750.017255  5.948888e+06
# VVC17-2       376750.017255  5.948888e+06
# VVC17-3       376750.017255  5.948888e+06
# VVC19-4       375938.044854  5.956797e+06
# VVC20-1       375508.096054  5.958457e+06
# VVC20-2       375508.096054  5.958457e+06
# VVC20-4       375508.096054  5.958457e+06
# W4-3          381204.165000  5.946797e+06
# W5-2          381303.200000  5.946609e+06

# %%
import utm
lat, lon = utm.to_latlon(out.long_utm.values, out.lat_utm.values, 32, 'U')

out['lon'] = lon
out['lat'] = lat

out
# Out:
#                    long_utm       lat_utm       lon        lat
# core_section
# N11-1         372919.501165  5.953943e+06  7.074159  53.718663
# N11-2         372919.501165  5.953943e+06  7.074159  53.718663
# N13-2         376934.301491  5.953075e+06  7.135310  53.711828
# N13-3         376934.301491  5.953075e+06  7.135310  53.711828
# N13-4         376934.301491  5.953075e+06  7.135310  53.711828
# N14-1         376864.372782  5.952926e+06  7.134310  53.710480
# N14-2         376864.372782  5.952926e+06  7.134310  53.710480
# N15-1         376821.653110  5.952809e+06  7.133710  53.709410
# N15-2         376821.653110  5.952809e+06  7.133710  53.709410
# N15-4         376821.653110  5.952809e+06  7.133710  53.709410
# N16-1         376841.734706  5.952266e+06  7.134230  53.704537
# N16-2         376841.734706  5.952266e+06  7.134230  53.704537
# N16-4         376841.734706  5.952266e+06  7.134230  53.704537
# N18-2         377685.385503  5.951345e+06  7.147367  53.696467
# N18-5         377685.385503  5.951345e+06  7.147367  53.696467
# N23-1         378651.401930  5.951120e+06  7.162078  53.694667
# N23-2         378651.401930  5.951120e+06  7.162078  53.694667
# N23-3         378651.401930  5.951120e+06  7.162078  53.694667
# N23-4         378651.401930  5.951120e+06  7.162078  53.694667
# N25-3         379239.920731  5.951386e+06  7.170883  53.697192
# N26-4         379241.876966  5.951688e+06  7.170795  53.699912
# N28-1         380346.656541  5.951310e+06  7.187667  53.696767
# N30-4         381025.867668  5.951120e+06  7.198022  53.695215
# N31-1         381652.274887  5.951048e+06  7.207532  53.694708
# N32-3         381686.377659  5.951042e+06  7.208050  53.694667
# N34-2         382519.412273  5.950893e+06  7.220717  53.693517
# N36-4         379235.019000  5.950549e+06  7.171135  53.689674
# N38-4         382069.307000  5.950267e+06  7.214141  53.687793
# N40-1         382740.034902  5.950702e+06  7.224129  53.691851
# N40-4         382740.034902  5.950702e+06  7.224129  53.691851
# N41-2         383277.960086  5.950829e+06  7.232223  53.693108
# N41-4         383277.960086  5.950829e+06  7.232223  53.693108
# N43-1         378293.250000  5.949892e+06  7.157139  53.683558
# N43-3         378293.250000  5.949892e+06  7.157139  53.683558
# N46-1         381670.230000  5.950153e+06  7.208145  53.686675
# N49-3         378326.157000  5.948519e+06  7.158175  53.671227
# N50-2         380290.610002  5.948761e+06  7.187802  53.673856
# N71-1         377706.964230  5.951329e+06  7.147700  53.696330
# N71-3         377706.964230  5.951329e+06  7.147700  53.696330
# N71-4         377706.964230  5.951329e+06  7.147700  53.696330
# N85-3         372220.456356  5.954347e+06  7.063405  53.722128
# VC13-2        379692.999989  5.950222e+06  7.178194  53.686843
# VVC09-4       385148.892261  5.950229e+06  7.260767  53.688133
# VVC16-4       376509.279955  5.949859e+06  7.130155  53.682840
# VVC17-1       376750.017255  5.948888e+06  7.134184  53.674169
# VVC17-2       376750.017255  5.948888e+06  7.134184  53.674169
# VVC17-3       376750.017255  5.948888e+06  7.134184  53.674169
# VVC19-4       375938.044854  5.956797e+06  7.118731  53.745032
# VVC20-1       375508.096054  5.958457e+06  7.111546  53.759844
# VVC20-2       375508.096054  5.958457e+06  7.111546  53.759844
# VVC20-4       375508.096054  5.958457e+06  7.111546  53.759844
# W4-3          381204.165000  5.946797e+06  7.202375  53.656420
# W5-2          381303.200000  5.946609e+06  7.203945  53.654748

# %%
out.to_csv('results/r_section_GPS_{}.csv'.format(date))
print(date)
# Out:
# 20220125

# %% [markdown]
# # Data distribution
# Modified from `ML_element_17.ipynb`.

# %%
from wasafacies import PrepareData

prepare = PrepareData()
facies, id_list = prepare.create_recla()
norm_df = prepare.create_raw(facies=facies, id_list=id_list)

# %%
grouping = norm_df[['facies', 'core_section']].groupby('facies').count()
grouping.columns = ['data_point']

# %%
sections = []
for fa in grouping.index:
    sections.append(
        len(norm_df.loc[norm_df.facies == fa, 'core_section'].unique())
    )

grouping['core_section'] = sections

# %%
from wasafacies import Evaluation
eva = Evaluation()
grouping.index = eva.get_Facies()

grouping
# Out:
#      data_point  core_section
# hsm        1768             6
# hcf        2795             7
# lcf        1220             3
# sf         3937             8
# mf         1343             5
# la         1165             5
# pt          855             6
# so          405             4
# pm         2390             7
# pef        2983             8
# mo          962             3

# %%
fig, axes = plt.subplots(1, 2, sharey='row', gridspec_kw={'width_ratios':[2, 1]}, figsize=(5, 3.54))
for ax, col in zip(axes, ['data_point', 'core_section']):
    ax.barh(y=grouping.index[::-1], width=grouping[col][::-1], color='C0', alpha=.7)
    for i, row in grouping.iterrows():
        ax.text(x=row[col], 
                y=i, 
                s=row[col], va='center', size=8)

axes[0].set_xlim(0, 4500)
axes[0].set_xlabel('Number of data points')
axes[0].set_ylabel('Sediment facies')
axes[1].set_xlabel('Number of core sections')
plt.tight_layout()
fig.subplots_adjust(wspace=0.05)
fig.savefig('results/r_data_distribution_{}.png'.format(date))
print(date)
# Out:
# 20220216

# %% [markdown]
# # CV scores
# modified from `ML_element_17.ipynb`.

# %%
# the best sc
import glob
grid_df = pd.DataFrame()
data_list = []
alg_list = []
pca_list = []

for data_dir in glob.glob('results/r_*_grid_20220120.csv'):
    
    X1 = pd.read_csv(data_dir, index_col=0)

    for mask, pca in zip([X1.param_pca.isna(), ~X1.param_pca.isna()], ['no', 'yes']):
        X2 = X1[mask].reset_index(drop=True)
        grid_df = pd.concat([grid_df, X2.iloc[np.argmax(X2.mean_test_score), :]], axis=1, join='outer')
        data_list.append(data_dir.split('_')[1])
        alg_list.append(data_dir.split('_')[2])
        pca_list.append(pca)

grid_df = grid_df.T
grid_df['data'] = data_list
grid_df['alg'] = alg_list
grid_df['pca'] = pca_list

grid_df
# Out:
#    mean_fit_time std_fit_time mean_score_time std_score_time param_lr__C  \
# 3       1.550458     0.218712        0.005439       0.000174         0.1
# 3       1.015444     0.159766         0.00704       0.000952         0.1
# 5     100.910202     4.312628        3.083748       0.678184         NaN
# 7      24.793201     1.035902        2.143548       0.333112         NaN
# 24      2.856047     0.270792        1.314926       0.080586         NaN
# 17     13.144488     0.825871         2.37145        0.10853         NaN
# 20      14.12607     1.708435        9.673466       0.464898         NaN
# 32      2.296071     0.151812        0.830215       0.061374         NaN
# 1       9.669957     1.855004        0.017828       0.001477       0.001
# 0       1.546021     0.026087        0.031302       0.003165      0.0001
# 1       0.802569     0.083521        0.006429       0.000551       0.001
# 0       0.592256     0.057314        0.008032       0.000737      0.0001
# 0       3.730722     0.443167        1.430471       0.464203         NaN
# 2      87.317151     3.927578        6.462482       0.419563         NaN
# 8     724.738881    27.510787         6.42017       0.353277         NaN
# 0       2.422476     0.128899        0.940426       0.082003         NaN
# 21      1.465347     0.137716        0.843954       0.050149         NaN
# 26      1.737713     0.132488        0.871051        0.06116         NaN
#
#                             param_pca  \
# 3                                 NaN
# 3                    PCA(whiten=True)
# 5                                 NaN
# 7                    PCA(whiten=True)
# 24                                NaN
# 17                   PCA(whiten=True)
# 20                                NaN
# 32  PCA(n_components=50, whiten=True)
# 1                                 NaN
# 0   PCA(n_components=50, whiten=True)
# 1                                 NaN
# 0                    PCA(whiten=True)
# 0                                 NaN
# 2                    PCA(whiten=True)
# 8                                 NaN
# 0   PCA(n_components=50, whiten=True)
# 21                                NaN
# 26                   PCA(whiten=True)
#
#                                                params split0_test_score  \
# 3                         {'lr__C': 0.1, 'pca': None}          0.523349
# 3             {'lr__C': 0.1, 'pca': PCA(whiten=True)}          0.513402
# 5   {'pca': None, 'rf__max_depth': 5, 'rf__n_estim...          0.515039
# 7   {'pca': PCA(whiten=True), 'rf__max_depth': 10,...          0.511633
# 24  {'pca': None, 'scaling': StandardScaler(), 'sv...          0.596411
# 17  {'pca': PCA(whiten=True), 'scaling': StandardS...          0.627999
# 20  {'pca': None, 'svc__C': 1.0, 'svc__gamma': 0.001}          0.564751
# 32  {'pca': PCA(n_components=50, whiten=True), 'sv...          0.529885
# 1                       {'lr__C': 0.001, 'pca': None}          0.537968
# 0   {'lr__C': 0.0001, 'pca': PCA(n_components=50, ...          0.609298
# 1                       {'lr__C': 0.001, 'pca': None}          0.624848
# 0          {'lr__C': 0.0001, 'pca': PCA(whiten=True)}          0.650552
# 0   {'pca': None, 'rf__max_depth': 3, 'rf__n_estim...          0.587805
# 2   {'pca': PCA(whiten=True), 'rf__max_depth': 3, ...          0.583702
# 8   {'pca': None, 'rf__max_depth': 10, 'rf__n_esti...          0.564444
# 0   {'pca': PCA(n_components=50, whiten=True), 'rf...          0.565835
# 21   {'pca': None, 'svc__C': 1.0, 'svc__gamma': 0.01}          0.537246
# 26  {'pca': PCA(whiten=True), 'svc__C': 10.0, 'svc...          0.508221
#
#    split1_test_score split2_test_score  ... std_test_score rank_test_score  \
# 3           0.571322          0.543248  ...       0.079434               4
# 3           0.573458          0.543323  ...       0.072596               1
# 5            0.58998          0.570078  ...       0.087442               1
# 7           0.550157          0.505814  ...        0.07147              13
# 24          0.719259          0.615897  ...       0.063259               1
# 17          0.627036          0.593091  ...       0.058442               6
# 20           0.66707          0.543581  ...       0.087841               3
# 32          0.634522          0.619588  ...       0.076605               1
# 1           0.626083          0.551949  ...       0.082669              10
# 0            0.65571          0.623762  ...       0.078838               1
# 1           0.740763          0.645768  ...       0.083694               1
# 0           0.655509          0.644598  ...       0.054391               2
# 0           0.643223          0.681659  ...       0.127118               6
# 2           0.677679          0.619868  ...       0.090008               1
# 8           0.585939           0.55452  ...        0.09075               1
# 0           0.627286          0.489272  ...       0.073715               7
# 21           0.61612           0.53571  ...        0.07843               3
# 26          0.615495          0.554255  ...        0.07184               1
#
#    param_rf__max_depth param_rf__n_estimators     param_scaling param_svc__C  \
# 3                  NaN                    NaN               NaN          NaN
# 3                  NaN                    NaN               NaN          NaN
# 5                    5                   5000               NaN          NaN
# 7                   10                   1000               NaN          NaN
# 24                 NaN                    NaN  StandardScaler()          1.0
# 17                 NaN                    NaN  StandardScaler()          0.1
# 20                 NaN                    NaN               NaN          1.0
# 32                 NaN                    NaN               NaN        100.0
# 1                  NaN                    NaN               NaN          NaN
# 0                  NaN                    NaN               NaN          NaN
# 1                  NaN                    NaN               NaN          NaN
# 0                  NaN                    NaN               NaN          NaN
# 0                    3                    100               NaN          NaN
# 2                    3                   5000  StandardScaler()          NaN
# 8                   10                  10000               NaN          NaN
# 0                    3                    100               NaN          NaN
# 21                 NaN                    NaN               NaN          1.0
# 26                 NaN                    NaN               NaN         10.0
#
#    param_svc__gamma  data  alg  pca
# 3               NaN   raw   lr   no
# 3               NaN   raw   lr  yes
# 5               NaN   raw   rf   no
# 7               NaN   raw   rf  yes
# 24            0.001  roll  svc   no
# 17            0.001  roll  svc  yes
# 20            0.001    2d  svc   no
# 32            0.001    2d  svc  yes
# 1               NaN    2d   lr   no
# 0               NaN    2d   lr  yes
# 1               NaN  roll   lr   no
# 0               NaN  roll   lr  yes
# 0               NaN  roll   rf   no
# 2               NaN  roll   rf  yes
# 8               NaN    2d   rf   no
# 0               NaN    2d   rf  yes
# 21             0.01   raw  svc   no
# 26            0.001   raw  svc  yes
#
# [18 rows x 23 columns]

# %%
grid_df.shape
# Out:
# (18, 23)

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.8, 3.54))
for data in ['raw', 'roll', '2d']:
    # small trick to plot part of legend
    if data == 'roll':
        ax.legend(loc='lower right', ncol=3)
    for alg, color in zip(['lr', 'svc', 'rf'], ['C0', 'C1', 'C2']):
        # without PCA
        mask = (grid_df.data == data) & (grid_df.alg == alg) & (grid_df.pca == 'no')
        ax.scatter(
            data, 
            grid_df.mean_test_score[mask], 
            facecolors=color,
            label=alg.upper())
        # with PCA
        mask = (grid_df.data == data) & (grid_df.alg == alg) & (grid_df.pca == 'yes')
        ax.scatter(
            data, 
            grid_df.mean_test_score[mask], 
            facecolors='none', 
            edgecolors=color,
            linewidths=1,
            label='{}(pca)'.format(alg.upper()))
ax.set_xticklabels(['raw', 'rolling', '2d'])
ax.set_xlabel('Data representation')
ax.set_ylabel('CV score')

plt.savefig('results/r_grids_{}.png'.format(date))
print(date)
# Out:
# 20220216
# /home/users/aslee/miniconda3/envs/wasafacies/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# # Bi-axis plot for accuracy and number of boundaries
# It's the evaluation of the test set.

# %%
eva_df = pd.DataFrame(
    {'data': ['raw', 'rolling', '2d'],
     'accuracy': [0.71, 0.78, 0.75],
     'boundary': [591, 98, 156]}
     )

# %%
# histogram of the max. probability
fig, ax1 = plt.subplots(figsize=(3.8, 3.54))
color = 'C0'
ax1.bar(x=eva_df.data, height=eva_df.boundary, color=color, alpha=.7)
ax1.set_ylabel('Number of boundaries', c=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xlabel('Data representation')

# error rate in each range of max. probability
color = 'C1'
ax2 = ax1.twinx()
ax2.plot(eva_df.data, eva_df.accuracy*100, marker='o', c=color)
ax2.set_ylabel('Accuracy (%)', c=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout() 

fig.savefig('results/r_test_eva_biplot_{}.png'.format(date))
print(date)
# Out:
# 20220216

# %% [markdown]
# # Combine the CV scores and the bi-axis plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(7.25, 3.54))

# CV scores
for data in ['raw', 'roll', '2d']:
    # small trick to plot part of legend
    if data == 'roll':
        axes[0].legend(loc='lower right', ncol=3, handlelength=.3)
    for alg, color in zip(['lr', 'svc', 'rf'], ['C0', 'C1', 'C2']):
        # without PCA
        mask = (grid_df.data == data) & (grid_df.alg == alg) & (grid_df.pca == 'no')
        axes[0].scatter(
            data, 
            grid_df.mean_test_score[mask], 
            facecolors=color,
            label=alg.upper())
        # with PCA
        mask = (grid_df.data == data) & (grid_df.alg == alg) & (grid_df.pca == 'yes')
        axes[0].scatter(
            data, 
            grid_df.mean_test_score[mask], 
            facecolors='none', 
            edgecolors=color,
            linewidths=1,
            label='{}(pca)'.format(alg.upper()))
            
axes[0].set_xticklabels(['raw', 'rolling', '2d'])
axes[0].set_xlabel('Data representation')
axes[0].set_ylabel('CV score')

# bi-axis plot
# distribution
color = 'C0'
axes[1].bar(x=eva_df.data, height=eva_df.boundary, color=color, alpha=.5)
axes[1].set_ylabel('Number of boundaries', c=color)
axes[1].tick_params(axis='y', labelcolor=color)
axes[1].set_xlabel('Data representation')

# error rate in each range of max. probability
color = 'C1'
ax2 = axes[1].twinx()
ax2.plot(eva_df.data, eva_df.accuracy*100, marker='o', c=color)
ax2.set_ylabel('Accuracy (%)', c=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout() 
plt.savefig('results/r_grids+biaxis_{}.png'.format(date))
print(date)
# Out:
# /home/users/aslee/miniconda3/envs/wasafacies/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
# 20220216

# %% [markdown]
# # Comparison between the actual and predicted result
# In test set. It's modified from ML_element_17.ipynb. After changing the marker to "hline", the overlapping issue is solved. However, aliasing happens because the pixcel resolution dosen't match the marker resolution (1 m core having 1000 marker in ~2 inches interval). I've increased the resolution to 600 dpi and let it be. I can't do much about it...

# %%
y_df = pd.read_csv('results/r_ys_20220120.csv', index_col=0)

# %%
from wasafacies import Evaluation
eva = Evaluation()
Facies = eva.get_Facies()
Facies
# Out:
# array(['hsm', 'hcf', 'lcf', 'sf', 'mf', 'la', 'pt', 'so', 'pm', 'pef',
#        'mo'], dtype=object)

# %%
y_df = pd.concat([
        pd.read_csv('data/info.cleaned.all.csv', index_col=0, usecols=['composite_id', 'section_depth_mm']),
        y_df],
    axis=1, join='inner'
)
y_df
# Out:
#              section_depth_mm  y_raw  y_roll  y_2d  y core_section
# N11_02945               220.0      5     NaN   NaN  4        N11-1
# N11_02947               222.0      5     NaN   NaN  4        N11-1
# N11_02949               224.0      5     NaN   NaN  4        N11-1
# N11_02951               226.0      5     NaN   NaN  4        N11-1
# N11_02953               228.0      5     NaN   NaN  4        N11-1
# ...                       ...    ...     ...   ... ..          ...
# VVC20_04735             990.0      7     NaN   NaN  9      VVC20-1
# VVC20_04737             992.0      7     NaN   NaN  9      VVC20-1
# VVC20_04739             994.0      7     NaN   NaN  9      VVC20-1
# VVC20_04741             996.0      7     NaN   NaN  9      VVC20-1
# VVC20_04743             998.0      7     NaN   NaN  9      VVC20-1
#
# [3942 rows x 6 columns]

# %%
plt.rcParams['savefig.dpi'] = 600
def plot_facies(data_df, section_list, y_pred, Facies, depth, fig_no):
    """
    data_df is the dataframe having info and labels.
    section_list can be a list of the core sections you want to plot.
    y_pred is the column name of labels you want to plot.
    Faceis is a list of facies names.
    depth is the str indicating the depth you want to plot, 
    "composite_depth_mm" or "section_depth_mm".
    """
    fig, axes = plt.subplots(2, 3, figsize = (6, 6.25), sharey='row') 
    for core_section, ax in zip(section_list, axes.ravel()):
        X = data_df[data_df.core_section == core_section]        
        ax.scatter(X.y - .2, X[depth]*.001, marker = '_', s = 3, lw = .2, label = 'Description')
        ax.scatter(X[y_pred] + .15, X[depth]*.001, marker = '_', s = 3, lw = .2, label = 'Prediction')
        #ax.set_ylim(ax.get_ylim()[::-1])
        ax.set_ylim(1.2, 0)
        ax.set_xlim(-.5, len(Facies))
        ax.set_xticks(range(len(Facies)))
        ax.set_xticklabels(Facies, rotation = 90)
        ax.set_title(core_section)
        ax.grid(visible=True, axis='x', color='0.95', lw=.7)
        ax.spines["left"].set_position(("axes", -.2))
        ax.tick_params('y', labelsize = 8, labelrotation = 90)
        
    #axes[0, 0].legend(markerscale=3)
    axes[0, 0].set_ylabel('{} depth (m)'.format(depth.split('_')[0].capitalize()))
    axes[1, 0].set_ylabel('{} depth (m)'.format(depth.split('_')[0].capitalize()))
    #plt.subplots_adjust(wspace=.6, hspace=.3)
    plt.tight_layout()
    fig.savefig('results/r_{}_bysection_{}_{}.png'.format(y_pred, date, fig_no))
plot_facies(y_df, y_df.core_section.unique()[:6], 'y_roll', Facies, 'section_depth_mm', 1)

# %%
def plot_facies(data_df, section_list, y_pred, Facies, depth, fig_no):
    """
    data_df is the dataframe having info and labels.
    section_list can be a list of the core sections you want to plot.
    y_pred is the column name of labels you want to plot.
    Faceis is a list of facies names.
    depth is the str indicating the depth you want to plot, 
    "composite_depth_mm" or "section_depth_mm".
    """
    fig, axes = plt.subplots(2, 3, figsize = (6, 6.25), sharey='row') 
    for core_section, ax in zip(section_list, axes.ravel()):
        X = data_df[data_df.core_section == core_section]        
        ax.scatter(X.y - .2, X[depth]*.001, marker = '_', s = 3, lw = .2, label = 'Description')
        ax.scatter(X[y_pred] + .15, X[depth]*.001, marker = '_', s = 3, lw = .2, label = 'Prediction')
        #ax.set_ylim(ax.get_ylim()[::-1])
        ax.set_ylim(1.2, 0)
        ax.set_xlim(-.5, len(Facies))
        ax.set_xticks(range(len(Facies)))
        ax.set_xticklabels(Facies, rotation = 90)
        ax.set_title(core_section)
        ax.grid(visible=True, axis='x', color='0.95', lw=.7)
        ax.spines["left"].set_position(("axes", -.2))
        ax.tick_params('y', labelsize = 8, labelrotation = 90)
        
    #axes[0, 0].legend(markerscale=3)
    axes[0, 0].set_ylabel('{} depth (m)'.format(depth.split('_')[0].capitalize()))
    axes[1, 0].set_ylabel('{} depth (m)'.format(depth.split('_')[0].capitalize()))
    #plt.subplots_adjust(wspace=.6, hspace=.3)
    axes[1, 2].remove() 
    plt.tight_layout()
    fig.savefig('results/r_{}_bysection_{}_{}.png'.format(y_pred, date, fig_no))
plot_facies(y_df, y_df.core_section.unique()[6:], 'y_roll', Facies, 'section_depth_mm', 2)
print(date)
# Out:
# 20220211

# %% [markdown]
# # Check core for demo
# Check how to correctly align the core image to the predicted probability.

# %%
compile_df = pd.read_csv('results/r_prob_20220124.csv', index_col=0)

core_section = 'N31-1'

# %%
plt.scatter(compile_df.loc[compile_df.core_section == 'N31-1', 'section_depth_mm'], 
    np.repeat(1, sum(compile_df.core_section == 'N31-1')),
    s=1
    )

# %%
X = compile_df.loc[compile_df.core_section == 'N31-1', 'section_depth_mm']
print(X.min(), X.max(), len(X))
# Out:
# 27.36 923.36 449

# %%
(X.max()-X.min())/2
# Out:
# 448.0

# %% [markdown]
# Okay, there is no vacancy in the scanning data.

# %% [markdown]
# ## Modfiy the demo figure
# Modified from `ML_element_18.ipynb`.

# %%
from wasafacies import Evaluation

eva = Evaluation()
Facies = eva.get_Facies()

# %%
X = compile_df.loc[compile_df.core_section == core_section, compile_df.columns[-11:]]
max_pro = pd.concat(
    [compile_df.loc[compile_df.core_section == core_section, 'section_depth_mm'], X.apply(np.max, axis=1)],
    axis=1, join='inner'
    )
max_pro.columns = ['section_depth_mm', 'max_prob']
max_pro
# Out:
#               section_depth_mm  max_prob
# composite_id
# N31_03232                27.36  0.537764
# N31_03234                29.36  0.514403
# N31_03236                31.36  0.500545
# N31_03238                33.36  0.455903
# N31_03240                35.36  0.311022
# ...                        ...       ...
# N31_04120               915.36  0.675883
# N31_04122               917.36  0.659928
# N31_04124               919.36  0.660494
# N31_04126               921.36  0.667626
# N31_04128               923.36  0.661988
#
# [449 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize=(4.75, 5), gridspec_kw={'width_ratios': [1, 4]})

axes[0].plot(max_pro.max_prob, max_pro.section_depth_mm*.001, alpha=.9)
axes[0].set_ylim(max_pro.section_depth_mm.max()*.001, max_pro.section_depth_mm.min()*.001)
axes[0].set_xlabel('Max. prob.')
axes[0].set_ylabel('Section depth (m)')

sns.heatmap(X, cmap='Greens', xticklabels=Facies, vmax=1, vmin=0, 
            yticklabels=False, ax=axes[1], 
            cbar_kws = {'label' : 'Probability', 'ticks': [0, 0.2, 0.4, 0.6, 0.8, 1]})

axes[1].set_ylabel('')


plt.tight_layout()
plt.subplots_adjust(wspace=.2)
fig.savefig('results/r_demo_prob_roll+lr_{}_{}.png'.format(core_section, date))
print(date)
# Out:
# 20220214

# %%
mask = compile_df.y == compile_df.y_roll
cor = compile_df.loc[mask, compile_df.columns[-11:]].apply(np.max, axis=1).values
incor = compile_df.loc[~mask, compile_df.columns[-11:]].apply(np.max, axis=1).values

error_rates = []

for i in range(1, 10):
    i = i*.1
    mask_cor = (cor > i) & (cor <= i+.1)
    mask_inc = (incor > i) & (incor <= i+.1)
    error_rates.append(mask_inc.sum() / (mask_cor.sum()+mask_inc.sum()))

# %%
# histogram of the max. probability
fig, ax1 = plt.subplots(figsize=(3, 5))
bins = np.linspace(.1, 1.0, 10)
ax1.hist(cor, label='Correct', alpha=.5, bins=bins)
ax1.hist(incor, label='Incorrect', alpha=.6, bins=bins)
ax1.set_ylim(0, 675)
ax1.legend()
ax1.set_ylabel('Count')
ax1.set_xlabel('Max. prob.')

# error rate in each range of max. probability
color = 'C2'
ax2 = ax1.twinx()
ax2.plot(np.linspace(0.15, 0.95, 9), np.array(error_rates)*100, marker='o', c=color, ms=4)
ax2.set_ylabel('Error rate (%)', c=color)
ax2.set_xticks(np.linspace(0.2, 1, 5))
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout() 

fig.savefig('results/r_test_prob_distribution_{}.png'.format(date))
print(date)
# Out:
# 20220214

# %%
np.linspace(0.2, 0.8, 4)
# Out:
# array([0.2, 0.4, 0.6, 0.8])
